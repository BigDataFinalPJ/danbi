# %%
import pandas as pd


df = pd.read_csv('부산광역시.csv' , encoding = 'cp949')
df_2 = pd.read_csv('../../../../데이터센터정리.csv' , encoding = 'cp949')

df = df.astype({'시군구법정동번지코드' : 'str',
                '시군구법정동번코드' : 'str'})
df.head()
# Out:
#    Unnamed: 0      시군구법정동번지코드     시군구법정동번코드    시군구법정동코드  본번  부번  사용량_KWH  \
# 0      158562  26230106007232  262301060072  2623010600  72  32      784
# 1      158561  26230106007217  262301060072  2623010600  72  17     3278
# 2      158560   2623010600718  262301060071  2623010600  71   8      295
# 3      158559  26230106007022  262301060070  2623010600  70  22     5928
# 4      158558   2623010600511  262301060051  2623010600  51   1     1789
#
#      시도명  시군구명 법정동명        새주소대로로코드  새주소대로로명 새주소본번 새주소부번
# 0  부산광역시  부산진구  연지동  262303129029.0      성지로   6.0   0.0
# 1  부산광역시  부산진구  연지동  262303129029.0      성지로  12.0   1.0
# 2  부산광역시  부산진구  연지동  262303129029.0      성지로  16.0   0.0
# 3  부산광역시  부산진구  연지동  262303129029.0      성지로  30.0   0.0
# 4  부산광역시  부산진구  연지동  262304187444.0  성지로14번길  77.0   0.0

# %%
df_2.head()
# Out:
#          시군구법정동번지코드       시군구법정동번코드    시군구법정동코드     번   지  \
# 0   421301170018946  42130117001894  4213011700  1894   6
# 1  4213011700204710  42130117002047  4213011700  2047  14
# 2  4213011700204710  42130117002047  4213011700  2047  10
# 3   421103102210000  42110310221000  4211031022  1000   0
# 4    42110126006500   4211012600650  4211012600   650   0
#
#                             주소  분류         기업                       이름  \
# 0    강원 원주시 건강로 32(반곡동 1894-6)  공공   국민건강보험공단           국민건강보험공단 데이터센터
# 1  강원 원주시 입춘로 130(반곡동 2047-14)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (2사옥)
# 2   강원 원주시 혁신로 60(반곡동 2047-10)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (1사옥)
# 3          강원 춘천시 동면 순환대로 1231  민간      NAVER              네이버 데이터센터 각
# 4          강원도 춘천시 옛경춘로 409-14  민간     오라클 춘천                   오라클 춘천
#
#                         비고 임차여부  전력사용량
# 0               O 자체 데이터센터    -    NaN
# 1                        -    -    NaN
# 2                        -    -    NaN
# 3  수력 발전소 통해 전체 전력량 70% 수급    -    NaN
# 4                        -    -    NaN

# %%
df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')

df_3
# Out:
#    Unnamed: 0       시군구법정동번지코드     시군구법정동번코드_x  시군구법정동코드_x    본번  부번  사용량_KWH  \
# 0      150938    2614010900301    261401090030  2614010900    30   1   136639
# 1      178574  263501050014630  26350105001463  2635010500  1463   0   170935
# 2      176937  262901090012291  26290109001229  2629010900  1229   1    42413
#
#      시도명  시군구명   법정동명  ...  시군구법정동코드_y     번  지                        주소  분류  \
# 0  부산광역시    서구  부민동1가  ...  2614010900    30  1        부산광역시 서구 대청로6번길 14  통신
# 1  부산광역시  해운대구     우동  ...  2635010500  1463  0  부산 해운대구 센텀7로 12(우동-1463)  공공
# 2  부산광역시    남구    문현동  ...  2629010900  1229  1            부산 남구 문현금융로 40  공공
#
#             기업               이름    비고 임차여부 전력사용량
# 0        LG U+  LG U+부산 센터 (아미)  기타분류    -   NaN
# 1  (재)APEC기후센터     APEC기후센터 전산실     -    -   NaN
# 2     한국자산관리공사      정보시스템실 시스템팀     -    -   NaN
#
# [3 rows x 25 columns]

# %%
df_3.to_csv("부산광역시_전력사용량.csv" , mode = 'w' , encoding= 'cp949')
