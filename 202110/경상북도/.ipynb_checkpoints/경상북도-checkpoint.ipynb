# %%
import pandas as pd


df = pd.read_csv('경상북도.csv' , encoding = 'cp949')
df_2 = pd.read_csv('../../../../데이터센터정리.csv' , encoding = 'cp949')

df = df.astype({'시군구법정동번지코드' : 'str',
                '시군구법정동번코드' : 'str'})
df.head()
# Out:
#    Unnamed: 0      시군구법정동번지코드      시군구법정동번코드    시군구법정동코드   본번  부번  사용량_KWH  \
# 0     1103001  47113330231860  4711333023186  4711333023  186   0     2847
# 1     1102999  47113330223950  4711333022395  4711333022  395   0      240
# 2     1102998  47113330223950  4711333022395  4711333022  395   0      240
# 3     1102941  47113320286401  4711332028640  4711332028  640   1      205
# 4     1102942  47113320288191  4711332028819  4711332028  819   1      623
#
#     시도명    시군구명     법정동명        새주소대로로코드  새주소대로로명  새주소본번 새주소부번
# 0  경상북도  포항시 북구  송라면 중산리  471133304012.0      보경로  283.0   0.0
# 1  경상북도  포항시 북구  송라면 하송리  471134712277.0  삼송길74번길   21.0   7.0
# 2  경상북도  포항시 북구  송라면 하송리  471134712277.0  삼송길74번길   21.0   5.0
# 3  경상북도  포항시 북구  청하면 이가리  471134712484.0      용산길  239.0   0.0
# 4  경상북도  포항시 북구  청하면 이가리  471134712484.0      용산길  227.0   0.0

# %%
df_2.head()
# Out:
#          시군구법정동번지코드       시군구법정동번코드    시군구법정동코드     번   지  \
# 0   421301170018946  42130117001894  4213011700  1894   6
# 1  4213011700204710  42130117002047  4213011700  2047  14
# 2  4213011700204710  42130117002047  4213011700  2047  10
# 3   421103102210000  42110310221000  4211031022  1000   0
# 4    42110126006500   4211012600650  4211012600   650   0
#
#                             주소  분류         기업                       이름  \
# 0    강원 원주시 건강로 32(반곡동 1894-6)  공공   국민건강보험공단           국민건강보험공단 데이터센터
# 1  강원 원주시 입춘로 130(반곡동 2047-14)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (2사옥)
# 2   강원 원주시 혁신로 60(반곡동 2047-10)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (1사옥)
# 3          강원 춘천시 동면 순환대로 1231  민간      NAVER              네이버 데이터센터 각
# 4          강원도 춘천시 옛경춘로 409-14  민간     오라클 춘천                   오라클 춘천
#
#                         비고 임차여부  전력사용량
# 0               O 자체 데이터센터    -    NaN
# 1                        -    -    NaN
# 2                        -    -    NaN
# 3  수력 발전소 통해 전체 전력량 70% 수급    -    NaN
# 4                        -    -    NaN

# %%
df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')

df_3
# Out:
#    Unnamed: 0       시군구법정동번지코드     시군구법정동번코드_x  시군구법정동코드_x    본번  부번  사용량_KWH  \
# 0     1112028  471303103412700  47130310341270  4713031034  1270   0    12229
# 1     1138397    4719012500941    471901250094  4719012500    94   1    44136
#
#     시도명 시군구명     법정동명  ...  시군구법정동코드_y     번  지  \
# 0  경상북도  경주시  양북면 장항리  ...  4713031034  1270  0
# 1  경상북도  구미시      임수동  ...  4719012500    94  1
#
#                                               주소  분류          기업           이름  \
# 0                            경북 경주시 양북면 불국로 1655  공공  한국수력원자력(주)  메인데이터센터(경주)
# 1  경상북도 구미시 3공단3로 302,경상북도 구미시 임수동 94-1 삼성전자 2공장  민간       삼성SDS     구미 데이터센터
#
#   비고 임차여부 전력사용량
# 0  -    -   NaN
# 1  -    -   NaN
#
# [2 rows x 25 columns]

# %%
df_3.to_csv("경상북도_전력사용량.csv" , mode = 'w' , encoding= 'cp949')
