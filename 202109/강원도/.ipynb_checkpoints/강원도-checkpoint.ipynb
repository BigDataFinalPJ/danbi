# %%
import pandas as pd


df = pd.read_csv('강원도.csv' , encoding = 'cp949')
df_2 = pd.read_csv('../../../../데이터센터정리.csv' , encoding = 'cp949')

df = df.astype({'시군구법정동번지코드' : 'str',
                 '시군구법정동번코드' : 'str'})
df.head()
# Out:
#    Unnamed: 0       시군구법정동번지코드       시군구법정동번코드    시군구법정동코드    본번  부번  사용량_KWH  \
# 0      680461  421301170011771  42130117001177  4213011700  1177   1      841
# 1      703323  421502502127074   4215025021270  4215025021   270  74      629
# 2      703322  421502502127035   4215025021270  4215025021   270  35      331
# 3      703321  421502502127035   4215025021270  4215025021   270  35      331
# 4      703320  421502502127021   4215025021270  4215025021   270  21      680
#
#    시도명 시군구명      법정동명        새주소대로로코드 새주소대로로명  새주소본번 새주소부번
# 0  강원도  원주시       반곡동  421303219015.0   동부순환로   57.0   0.0
# 1  강원도  강릉시  주문진읍 주문리  421503220040.0    주문북로    4.0   0.0
# 2  강원도  강릉시  주문진읍 주문리  421503220039.0     주문로  166.0   0.0
# 3  강원도  강릉시  주문진읍 주문리  421503220039.0     주문로  164.0   0.0
# 4  강원도  강릉시  주문진읍 주문리  421503220040.0    주문북로   12.0   0.0

# %%
print(df.dtypes)
# Out:
# Unnamed: 0     int64
# 시군구법정동번지코드    object
# 시군구법정동번코드     object
# 시군구법정동코드       int64
# 본번             int64
# 부번             int64
# 사용량_KWH        int64
# 시도명           object
# 시군구명          object
# 법정동명          object
# 새주소대로로코드      object
# 새주소대로로명       object
# 새주소본번         object
# 새주소부번         object
# dtype: object

# %%
#df_2 = df_2.astype({'시군구법정동번지코드' : 'float'})

# %%
print(df_2.dtypes)
# Out:
# 시군구법정동번지코드     object
# 시군구법정동번코드      object
# 시군구법정동코드        int64
# 번              object
# 지              object
# 주소             object
# 분류             object
# 기업             object
# 이름             object
# 비고             object
# 임차여부           object
# 전력사용량         float64
# dtype: object

# %%
df_2.head()
# Out:
#          시군구법정동번지코드       시군구법정동번코드    시군구법정동코드     번   지  \
# 0   421301170018946  42130117001894  4213011700  1894   6
# 1  4213011700204710  42130117002047  4213011700  2047  14
# 2  4213011700204710  42130117002047  4213011700  2047  10
# 3   421103102210000  42110310221000  4211031022  1000   0
# 4    42110126006500   4211012600650  4211012600   650   0
#
#                             주소  분류         기업                       이름  \
# 0    강원 원주시 건강로 32(반곡동 1894-6)  공공   국민건강보험공단           국민건강보험공단 데이터센터
# 1  강원 원주시 입춘로 130(반곡동 2047-14)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (2사옥)
# 2   강원 원주시 혁신로 60(반곡동 2047-10)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (1사옥)
# 3          강원 춘천시 동면 순환대로 1231  민간      NAVER              네이버 데이터센터 각
# 4          강원도 춘천시 옛경춘로 409-14  민간     오라클 춘천                   오라클 춘천
#
#                         비고 임차여부  전력사용량
# 0               O 자체 데이터센터    -    NaN
# 1                        -    -    NaN
# 2                        -    -    NaN
# 3  수력 발전소 통해 전체 전력량 70% 수급    -    NaN
# 4                        -    -    NaN

# %%
df_3 = pd.merge(df, df_2, how='inner' , on='시군구법정동번지코드')

df_3
# Out:
#    Unnamed: 0        시군구법정동번지코드     시군구법정동번코드_x  시군구법정동코드_x    본번  부번  \
# 0      686236   421103102210000  42110310221000  4211031022  1000   0
# 1      680966   421301170018946  42130117001894  4213011700  1894   6
# 2      680991  4213011700204710  42130117002047  4213011700  2047  10
# 3      680991  4213011700204710  42130117002047  4213011700  2047  10
#
#     사용량_KWH  시도명 시군구명    법정동명  ...  시군구법정동코드_y     번   지  \
# 0  13238987  강원도  춘천시  동면 만천리  ...  4211031022  1000   0
# 1      6018  강원도  원주시     반곡동  ...  4213011700  1894   6
# 2   1040885  강원도  원주시     반곡동  ...  4213011700  2047  14
# 3   1040885  강원도  원주시     반곡동  ...  4213011700  2047  10
#
#                             주소  분류         기업                       이름  \
# 0          강원 춘천시 동면 순환대로 1231  민간      NAVER              네이버 데이터센터 각
# 1    강원 원주시 건강로 32(반곡동 1894-6)  공공   국민건강보험공단           국민건강보험공단 데이터센터
# 2  강원 원주시 입춘로 130(반곡동 2047-14)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (2사옥)
# 3   강원 원주시 혁신로 60(반곡동 2047-10)  공공  건강보험심사평가원  건강보험심사평가원 ICT센터\n (1사옥)
#
#                         비고 임차여부 전력사용량
# 0  수력 발전소 통해 전체 전력량 70% 수급    -   NaN
# 1               O 자체 데이터센터    -   NaN
# 2                        -    -   NaN
# 3                        -    -   NaN
#
# [4 rows x 25 columns]

# %%
df_3.to_csv("강원도_전력사용량.csv" , mode = 'w' , encoding= 'cp949')
